# %% [markdown]
# # Assignment

# %% [markdown]
# ## Preblem Statement
# You are a data scintist working for a firm.You have been provided the dataset car_dataset.csv which includes details  of car
# #### Mileage (km/l) - tell  about total km car drive
# #### Engine Size (cc)- Engine cc
# #### Price (Lakhs)- price of car in lakhs

# %% [markdown]
# ## Task 1:Train a Linear Regreassion model
# - Import the data from the "car_dataset.csv" file and store it in a variable df.
# - Display the number of rows and columns in the dataset.
# - Display the first few rows of the dataset to get an overview.
# - Create a Linear Regression model and fit it using the Mileage (km/l) and Engine Size (cc) variable to predict Price (Lakhs)-
# - Print the model's coefficient and intercept.

# %%
# import dataset car_dataset.csv

#print no of rows and columns


# print few records

# %%
# Create a Linear Regression model and fit it

# %%
# Print the model's coefficients and intercept

# %%
# Predicting
